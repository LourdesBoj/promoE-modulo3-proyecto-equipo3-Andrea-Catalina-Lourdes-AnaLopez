# %%
import pandas as pd
import numpy as np

import sidetable as stb

import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import skew
from scipy.stats import kurtosistest
from scipy import stats

plt.rcParams['figure.figsize'] = (10, 10)
pd.options.display.max_columns = None

from datetime import datetime

# %%
df = pd.read_csv("data/bikes.csv", index_col= 0)
df.drop(["instant"], axis= 1, inplace= True)
df
# Out:
#          dteday  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# 0    01-01-2018  spring   0     1        0        6           0           2
# 1    02-01-2018  spring   0     1        0        0           0           2
# 2    03-01-2018  spring   0     1        0        1           1           1
# 3    04-01-2018  spring   0     1        0        2           1           1
# 4    05-01-2018  spring   0     1        0        3           1           1
# ..          ...     ...  ..   ...      ...      ...         ...         ...
# 725  27-12-2019  spring   1    12        0        4           1           2
# 726  28-12-2019  spring   1    12        0        5           1           2
# 727  29-12-2019  spring   1    12        0        6           0           2
# 728  30-12-2019  spring   1    12        0        0           0           1
# 729  31-12-2019  spring   1    12        0        1           1           2
#
#           temp     atemp      hum  windspeed  casual  registered   cnt
# 0    14.110847  18.18125  80.5833  10.749882     331         654   985
# 1    14.902598  17.68695  69.6087  16.652113     131         670   801
# 2     8.050924   9.47025  43.7273  16.636703     120        1229  1349
# 3     8.200000  10.60610  59.0435  10.739832     108        1454  1562
# 4     9.305237  11.46350  43.6957  12.522300      82        1518  1600
# ..         ...       ...      ...        ...     ...         ...   ...
# 725  10.420847  11.33210  65.2917  23.458911     247        1867  2114
# 726  10.386653  12.75230  59.0000  10.416557     644        2451  3095
# 727  10.386653  12.12000  75.2917   8.333661     159        1182  1341
# 728  10.489153  11.58500  48.3333  23.500518     364        1432  1796
# 729   8.849153  11.17435  57.7500  10.374682     439        2290  2729
#
# [730 rows x 15 columns]
